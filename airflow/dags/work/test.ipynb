# %%
from datetime import timedelta, datetime
# from services.morphs_tools import remove_emoji, remove_hashtags
# from services.database import morphs_to_mongo
from konlpy.tag import Okt
import re
import math
import pandas as pd
import pymongo
from pymongo import MongoClient

url = "mongodb+srv://startup_proj_de_08:Team08!!@team08.mi7hgs1.mongodb.net/?retryWrites=true&w=majority"

# %%
def pull_daily_mongo():
    """daily로 크롤링한 데이터 불러오기 (return:Dataframe)"""

    # mongodb 접속정보 host 는 docker 컨테이너 이름으로 지정해야함.
    client = MongoClient(url)

    # db 이름
    db = client["ConnectsLab"]

    # 연결할 컬랙션 이름
    collection = db["insta_daily_data_test"]

    # 쿼리
    query = {}
    daily_data = collection.find(query)
    daily_data_list = list(daily_data)

    # MongoDB 연결 종료
    client.close()

    return daily_data_list

# %%
data = pull_daily_mongo()

# %%
data
# Out:
# [{'_id': ObjectId('657aaaba631a40550e9a32fa'),
#   'user_name': '20210101_jelly',
#   'like_count': '23',
#   'caption': '👶🏻 23년 8월초 즈음,, 약 940일 전후의 일상기록!1. 몇개월부터였는지 잘 기억이 나지않지만, 꽤나 길었던 밥태기가 끝이나고는 계속 쭈욱~잘 먹는다. 활동성이 떨어지는 아이라서 그런가 소근육이 야무지게 발달한 것 같다. 젓가락질을 첨부터 좀 잘한 편인 것 같은데 이제는 밥도 젓가락으로 다 먹으려고 한다. 2. 여유로운 주말에 차려주는 쩰리 조식. 흑마늘(ㅋㅋㅋ)+사과+복숭아+구운계란+초당옥수수+우유+요플레 여기에 풀때기만 더 먹어주면 좋겠지만, 그건 안 먹겠지!3. ”시그럽다“... 외할머니한테 배운 사투리 😭4. 밥도 차려주고, 잘 먹으면 박수도 쳐줘야하고, 뒷정리까지 해줘야하는 우리네의 인생! 😂5.식후 운동은 쩰리가 아니라 쩰버지가 하는 듯!  그래도 이렇게 등에 매달려있는 공쥬님이 있어서 행복하지 않니? 🤪6. 잠자리 독서책으로 밤비노 루크 집어들고 오던 시절! 그리고 사진 찍지 마라며,,, 직접 카메라 꺼주겠다는 친절한 김쩰😅7. 엄마 나갈 때 손뽀뽀 날려주면서 쿨하게 보내주다니... 고오맙다 \U0001f979☺️8. 심지어 자기 이름 적힌 종이 들고가라며 나에게 건내주고 쿨하게 ”굿바이“해주었다.9. 여름 랑이모 방문의 날! 육아 만렙 이모한테 내가 노는 법을 좀 배워야겠다. 나말고 랑이모랑 놀겠다는 김쩰ㅋㅋㅋㅋ고마와 내 효녀딸10. 몬테수업중에 선생님께서 찍어주신 영상. 여전히 숫자 좋아하고 관심이 많아서 이제는 시계도 좋아한다. 디지털 시계를 곧 아날로그 시계로 바꾸어봐야겠다 🧐',
#   'upload_date': '2023-12-13'},
#  {'_id': ObjectId('657aaaba631a40550e9a32fb'),
#   'user_name': '20210101_jelly',
#   'like_count': '30',
#   'caption': '👯\u200d♀️ 쩰리 #영어노래 & 춤 모음그냥 가볍게 다닐 생각으로 등록한 영어 문센인데,쩰리가 여기서 배우는 노래를 너무 좋아해서 노래값은 한다고 생각한다 🤭☺️실제 수업에서는 오프닝과 클로징에서 노래만 하고,, 중간중간 동화책 읽거나 독후활동하는거는 일절 안한다고 함! 😒😒“아이 럽 맘🎶 ” 할 때 나한테 삿대질 하는거랑“마이 맘 럽스 미” 인데 “마이 맘 IC…” 비슷하게 발음하는 거 킹받네 😂 근데 너무 귀여움!💛',
#   'upload_date': '2023-12-13'},
#  {'_id': ObjectId('657aaaba631a40550e9a32fc'),
#   'user_name': '20210101_jelly',
#   'like_count': '11',
#   'caption': '📚 #30개월쯤 의 #책육아 기록! 📖 안녕 달그림 - 몇권 골라서 사봤는데, 수박수영장이야 워낙 유명하고 쩰리의 여름 최애 과일이었으니 당연히 좋아하고 자주 골라서 들고왔다. 또 “당근유치원”도 꽤 좋아했는데 나머지 책들은 아직 그다지 큰 관심이 없다.  ”우리는 언제나 다시만나“ 이 책은 한 워터룸에 놀러갔다가 읽어보게 된 책인데, 읽으면 엄마들이 괜시리 찡- 하게 되는 책이다. 나역시도 쩰리를 얼집 보내기 시작할 즈음 처음 읽어본 책이라 더더욱 와닿았고, 복직을 한 지금은 내가 더 쩰리를 보고싶어하고 안달나하는 것 같아서 왠지 모르게 날 위한 책인것 같아 (쩰리맘)개인 소장용으로 사보았다. 🤭📖뉴 차일드 애플-개정 누리과정에 맞춰진 내용이라고 소개하던데, 그건 잘 모르겠고 일단 소재가 매우 흥미롭다. 쩰리도 한번 읽으면 그 핵심 장면을 기억해서 몇번씩 이야기할 정도로 좋아했다. 책 전반적으로 색감도 부드럽고 내용도 좀 보드랍다는 느낌이 든다. 타공 기법을 활용한 부분이 많은데 이것도 쩰리가 이 전집을 좋아하는 이유인 것 같다. 첨에 더차일드애플, 베스트차일드애플, 뉴차일드애플 이름이 비스므리한게 넘 많아서 좀 헷갈렸는데, 그냥 계속 개정되면서 이름을 조금씩 바꾸는 것 같았다. 가장 최신버전의 책을 사면 되는 듯! 공구가로 사면 가성비 최고의 전집인 것 같다. 도레미곰 이후에 들이기 좋은 전집 \U0001faf6📖 푸름이 까꿍 -시기가 많이 지난 것 같은데, 막상 읽을 시기에는 크게 안 좋아해서 새책 수준의 상태를 오래 유지했다. 근데 시기가 지나고, 그래도 애기때 봤던게 기억이 나는지 좋아하길래 한참을 방출하지 못했던 책. 30개월이 되어서 읽으니 한자리에서 전집을 한바퀴 다 돌릴 수 있을 정도로 빨리 읽게되었다. 아주아주 가벼운 마음으로 책 후다닥 읽으면서 놀기 좋았다. 그치만 이제는 시기가 너무 지난 것 같아서 겨우겨우 설득해서 방출!📖사각사각 그림책-무슨 말이 더 필요하겠는가. 확신이 들지 않아서 당근으로 들여서 보여주다가, 결국 새책으로 50권을 다 들였다. 사실 좋아하는 책만 유독 많이 보긴하지만... (국민최애책 신호등 ㅋㅋ) 그래도 나머지 책들도 그다지 호불호 없이 보는 것 같다. 무엇보다 읽어주는 엄마도 재밌다. 내스타일이므로 좀더 오래 가지고 갈 것이다📖 밤비노루크 -이것도 공구로 들일 때 풀로 다 들였다. 너무 쉬운 것도 있고 아직은 어려운 것도 있는데, 첨에 엄청 좋아하면서 침대까지 집어들고 가지고 오더니 지금은 좀 시들해졌다. 좀더 거리두기를 하고 다시 도전해봐야지😇📖베이비올 수과학-이건 방출예정. 유명한 거에 비해,, 나의 총평은 그닥 비추. 비추라기 보다는 굳이 꼭 반드시 들일 필요는 없는 책인 것 같다. 이 수준으로 수개념, 과학 개념을 알려주는 책은 이미 다른 전집에도 조금씩 끼여있고 이 시기에는 그정도로 충분한 것 같다. 쩰리가 그래서 이 전집에 그다지 관심이 없었는 것 같기도하다. 오히려 더 어렵게 느껴질 수 있는 마퍼월은 좋아했으나 이거는 관심이 크게 없었다. 그래서 난 수특은 건너뛰고 수공을 바로 들여보았는데 오히려 수공은 좋아한다. 수특은 도서관에서 몇권 빌려와보니 그것도 좋아하는 듯! 수특과 수공이 기다리고 있으니 베이비올 수과학은 살포시 패쓰해도 괜찮을 것 같다. 📖아가월드 몬테소리-이건 책은 아니지만 그냥 여기에 끼워넣어보았다. 밤비노로 시작해서 클래식이 꽃이라하여 클래식까지 갔다가 결국...모던으로 꽃을 피워야한다길래 모던까지 다 질러버렸다. 이제 돌아올 수 없는 강을 건넜으니 열심히 해야한다. 달려보자!✅마지막 영상은...영어책에는 관심없고 숫자에만 관심있는 김쩰! 조만간 쇼파를 방출하고, 책장과 장난감 정리를 한판 해야겠다. 책이 여기저기 너무 산만하게 흩어져있으니 오히려 책을 덜 읽게되는 것 같기도한 내 느낌. 이게 원인은 아닐 수 있음 주의! ⚠️무튼 이거외에도 이 시기에 들인 책들이 많지만 일단은 요기까지 정리해두기! 우리아람이, 라라랜드, 바나나 세계창작, 지식특공대, 수학공룡, 과학공룡 등등 아직은 좀 더 지켜봐야할 책들 …커밍쑨\U0001faf6',
#   'upload_date': '2023-12-13'},
#  {'_id': ObjectId('657aaaba631a40550e9a32fd'),
#   'user_name': '20210101_jelly',
#   'like_count': '5',
#   'caption': '23.07.29 D+940🦓 #상주 #국립낙동강생물자원관 ✔️양평에서 대구로 오는 길에 경유지로 선택한 곳! 명성만큼이나 아이들이 너무나 좋아한 곳이었고, 알찼다 \U0001faf6 해설사의 설명도 너무나 유익해서 내가 더 듣고 싶을정도…! 지안이가 이해를 하면서 듣는 건지는 잘 모르겠지만 꽤 오랜시간 무리에서 이탈하지 않고 듣고 있었다 👏👏 (기린의 혀, 타조의 시력 등등에 대한 설명을 꽤 많이 해주셨는데~ 너무 신기해서 집에와서 자연관찰책을 찾아보았는데 자연관찰책에 안 나오는 내용도 많았다)장거리 운전으로 아빠들은 거의 산송장이었지만😂😂마지막 날까지 알찬 일정이었다. 2박3일 우리의 여름여행 끗!💛',
#   'upload_date': '2023-12-13'},
#  {'_id': ObjectId('657aaaba631a40550e9a32fe'),
#   'user_name': '_choco.seol_a',
#   'like_count': 0,
#   'caption': '🎅🏻🧴\U0001face 안그래도 요즘 뭘 써도 건조한 떠라 피부 걱정이었는데, 촉촉한 (?) 크리스마스 선물 받아서 다행이댜🤍🤍 오랜만에 촬영한다고 양갈래 협조해줘서 고마운 울 까투리 👧🏻💛 #아기모델 🏷️ 뷰티레시피 오 베이비 힘찬보습 아기로션 @b.recipe #쿠팡로켓배송 #베이비로션 #아기로션 #키즈로션 #아기로션추천 #아기바디로션 #키즈바디로션 #바디로션 #신생아로션 #유아로션 #어린이로션 #아토피로션 #육아필수템 #보습력좋은아기로선 #피부아토피 #끈적임없는바디로션 #유어로션추천 #출산선물 #뷰티레시피아기로션',
#   'upload_date': '2023-12-13'},
#  {'_id': ObjectId('657aaaba631a40550e9a32ff'),
#   'user_name': '_choco.seol_a',
#   'like_count': 0,
#   'caption': '#광고 떠라가 겨울맞이 새로운 로션을 받아보았어요🧴🤍 영상에 더 자세한 후기들이 나오니 끝까지 시청 부탁드려요:) 떠라의 셀프카메라 동영상도 있답니댜📹 요즘 진짜 로션만 보면 환장하고 달려드는 떠라, 이제 다 커서 로션도 본인이 혼자 바른대요\U0001f979🤍 여튼, 뷰티레시피 오베이비 힘찬보습 아기로션은 발림성과 보습력이 끝판왕인 제품인거같아요-! 패키지도 너무 귀염뽀짝하고 향은 또 얼마나 좋게요,,, 🤍 겨울로션들은 자칫하면 너무 두터워서 피부에서 겉도는 느낌이 나는데 이 아기로션은 바르자마자 사라락 흡수되는게 너무 맘에들어요! 덧바르르면 덧바를수록 효과도 더 좋아지고, 요즘 건조한 피부로 고생하는 아가들이나 침독이나 태열등으로 고생하는 신생아들, 기저귀 발진등 여러방면으로 쓰일 수 있는 아기로션이랍니다🤍 지금 뷰티레시피 공홈에서 거의 반값으로 할인중이니저도 왠지 쟁이러 가야겠어요,,🧴❤️❤️ 🏷️ 뷰티레시피 오 베이비 힘찬보습 아기로션 @b.recipe #쿠팡로켓배송 #베이비로션 #아기로션 #키즈로션 #아기로션추천 #아기바디로션 #키즈바디로션 #바디로션 #신생아로션 #유아로션 #어린이로션 #아토피로션 #육아필수템 #보습력좋은아기로선 #피부아토피 #끈적임없는바디로션 #유어로션추천 #출산선물 #뷰티레시피아기로션',
#   'upload_date': '2023-12-13'},
#  {'_id': ObjectId('657aaaba631a40550e9a3300'),
#   'user_name': '_choco.seol_a',
#   'like_count': 0,
#   'caption': '오늘의 촬영을 도와준 아빠토끼 덴지🐰🌺떠라 낮잠잘때 후딱 올려버리는 로션 광고 피드-🧴🤍 🏷️ 뷰티레시피 오 베이비 힘찬보습 아기로션 @b.recipe #쿠팡로켓배송 #베이비로션 #아기로션 #키즈로션 #아기로션추천 #아기바디로션 #키즈바디로션 #바디로션 #신생아로션 #유아로션 #어린이로션 #아토피로션 #육아필수템 #보습력좋은아기로선 #피부아토피 #끈적임없는바디로션 #유어로션추천 #출산선물 #뷰티레시피아기로션',
#   'upload_date': '2023-12-13'}]

# %%
import pandas as pd
num_parts = 3
# 데이터를 부분으로 나누는 함수 정의
def split_data(data, num_parts):
    total_len = len(data)
    part_size = total_len // num_parts
    split_data_dict = {f"data_{i+1}": data[i:i + part_size] for i in range(0, total_len, part_size)}
    return split_data_dict


# 데이터를 3 부분으로 나눔 (원하는 부분의 수로 변경 가능)
num_parts = 3
split_data_result = split_data(data, num_parts)

# %%
data_1 = pd.DataFrame(split_data_result["data_1"])
data_2 = pd.DataFrame(split_data_result["data_2"])
data_3 = pd.DataFrame(split_data_result["data_3"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 data_1 = pd.DataFrame(split_data_result["data_1"])
# ----> 2 data_2 = pd.DataFrame(split_data_result["data_2"])
#       3 data_3 = pd.DataFrame(split_data_result["data_3"])
#
# KeyError: 'data_2'

# %%
import pandas as pd

# 데이터를 부분으로 나누는 함수 정의
def split_data(data, num_parts):
    total_len = len(data)
    part_size = total_len // num_parts
    split_data_list = [pd.DataFrame(data[i:i + part_size]) for i in range(0, total_len, part_size)]
    return split_data_list

# 데이터를 3 부분으로 나눔 (원하는 부분의 수로 변경 가능)
num_parts = 3
split_data_result = split_data(data, num_parts)

# 리스트의 각 데이터프레임에 접근
for i, dataframe in enumerate(split_data_result, start=1):
    variable_name = f"data_{i}"
    globals()[variable_name] = dataframe

for i in range(1, num_parts + 1):
    variable_name = f"data_{i}"

# %%
def process_and_access_data(data, num_parts):
    # 데이터를 부분으로 나누는 함수 정의
    total_len = len(data)
    part_size = total_len // num_parts
    split_data_list = [pd.DataFrame(data[i:i + part_size]) for i in range(0, total_len, part_size)]

    # 리스트의 각 데이터프레임에 접근
    for i, dataframe in enumerate(split_data_list, start=1):
        variable_name = f"data_{i}"
        globals()[variable_name] = dataframe

    return split_data_list

# 데이터를 3 부분으로 나눔 (원하는 부분의 수로 변경 가능)
num_parts = 3
split_data_result = process_and_access_data(data, num_parts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 16
#      14 # 데이터를 3 부분으로 나눔 (원하는 부분의 수로 변경 가능)
#      15 num_parts = 3
# ---> 16 split_data_result = process_and_access_data(data, num_parts)
#
# NameError: name 'data' is not defined

# %%
data_1
# Out:
#                            _id    user_name like_count  \
# 0     6566c962a01b97c6e2cb63c7  to.gangnang        315
# 1     6566c962a01b97c6e2cb63c8  to.gangnang         93
# 2     6566c962a01b97c6e2cb63c9  to.gangnang        142
# 3     6566c962a01b97c6e2cb63ca  to.gangnang         61
# 4     6566c962a01b97c6e2cb63cb  to.gangnang         52
# ...                        ...          ...        ...
# 5911  6566c962a01b97c6e2cb7ade    yeony_m0m          0
# 5912  6566c962a01b97c6e2cb7adf    yeony_m0m          0
# 5913  6566c962a01b97c6e2cb7ae0    yeony_m0m          0
# 5914  6566c962a01b97c6e2cb7ae1    yeony_m0m          0
# 5915  6566c962a01b97c6e2cb7ae2    yeony_m0m          0
#
#                                                 caption upload_date
# 0                              낭이 루돌푸가 파는 성냥 사두세여~🙏🏻🫎❤️  2023-11-17
# 1     #협찬 강낭이 백일상 사진을 셀프 촬영만 해서 아쉬웠었는데디어제이스튜디오에서 좋은 ...  2023-11-22
# 2     #협찬 침쟁이의 데일리 턱받이 코디🤍침 많은 시기라, 턱받이 없는 순간은 상상할 수...  2023-11-21
# 3     꺄...🎄위시리스트 들이 채워져 나가고 있다생각보다 빨리 날아오고 있는 해외배송들 ...  2023-11-20
# 4     #협찬 라무르에서 선물로 준피부 유산균을 일주일간 챙겨먹어 보았는데요 😀평소처럼 보...  2023-11-20
# ...                                                 ...         ...
# 5911  오늘은 모자가아닌 장갑껴달라기한번 빨래해놓고 정리하려고꺼내놨는데 용케 집어들고 옴…...  2021-11-11
# 5912  신랑이 준 컵과일♥️어제저녁에 신랑이 거래처에 주고남은거라며 가저온 과일컵🙂오늘 서...  2021-11-10
# 5913  오늘의 서연🙂이틀내내 비가오더니 엄청 춥네여🥲엄마의 일용한 식사 탐내는 중그건 엄마...  2021-11-09
# 5914  집에서 모자는 왜쓰는거야어디서 가지고온 모자를 씌워달래서 씌워줬더니종일 쓰고 노는 ...  2021-11-08
# 5915  어제는 시댁식구모임♥️잠시 시부모님태우러 집에 갔다가할비랑 놀이터🙂모래를 밟으니 기...  2021-11-07
#
# [5916 rows x 5 columns]

# %%
data_2
# Out:
#                             _id     user_name like_count  \
# 9860   6566c962a01b97c6e2cb8a4b      ___j.nsa          0
# 9861   6566c962a01b97c6e2cb8a4c      ___j.nsa          0
# 9862   6566c962a01b97c6e2cb8a4d      ___j.nsa          0
# 9863   6566c962a01b97c6e2cb8a4e      ___j.nsa          0
# 9864   6566c962a01b97c6e2cb8a4f      ___j.nsa          0
# ...                         ...           ...        ...
# 19715  6566c962a01b97c6e2cbb0ca  chenvely_yun         28
# 19716  6566c962a01b97c6e2cbb0cb  chenvely_yun         18
# 19717  6566c962a01b97c6e2cbb0cc  chenvely_yun         25
# 19718  6566c962a01b97c6e2cbb0cd  chenvely_yun         15
# 19719  6566c962a01b97c6e2cbb0ce  chenvely_yun         20
#
#                                                  caption upload_date
# 9860   어제 떠아와 일상🫶감기로 병원진료보구 또 다른병원가서 코로나 검사하고너무 안쓰럽고 ...  2023-08-18
# 9861   신랑 코로나 걸려서 집콕했어요😭저희가족은 지금까지 코로나 잘피해다녔었는데날도 너무 ...  2023-08-14
# 9862   정말 오랜만에 셀카올려보기📸매번 애기 사진만 찍고 올리다 보니깐이제 셀카가 어색.....  2023-08-11
# 9863   이제는 매니큐어도 혼자 바르겠다네요??🤣사방팔방..바닥까지 질질 다흘리면서ㅠ엄마 청...  2023-08-11
# 9864   세차를 해보아요🫶요즘 말도 늘어가고 하루하루 커가는게 눈에 보이니깐신기하기도 하고 ...  2023-08-09
# ...                                                  ...         ...
# 19715  .먹는것 중에 젤 좋은 휘낭시에💛 스콘🧡 그담으로 좋은 파운드❤ 그리고 팥빵떡까지 ...  2021-05-21
# 19716  .예전부터 넘넘 가고싶었던 덕선제과❤내가 좋아하는 디저트 총집합🥰😍🤩분위기마저 넘나...  2021-05-21
# 19717  .점심시간 틈을 타 식빵사러🍞🥨🥯헷❤ 이 예쁜창가에 오래앉아있고싶건만.....장소 ...  2021-05-21
# 19718  .신나게 걸어가는 저 모습...ㅋㅋ❤씩씩하게도 가넹🥰😍🤩#18개월아기 #19개월아기...  2021-05-21
# 19719  .사랑하는 투 샷❤ 파~~아란 하늘과 빨~~간 꽃🌷 지나가다 우연히 이렇게 예쁜 골...  2021-05-20
#
# [9860 rows x 5 columns]
